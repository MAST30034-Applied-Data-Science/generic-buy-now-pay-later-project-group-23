# %% [markdown]
# ## This is just a notebook for checking some codes or merging things

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/curated/data_half_year.csv")

# %%
df
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
consumer_fraud = pd.read_csv('../data/tables/consumer_fraud_probability.csv') 
merchant_fraud = pd.read_csv('../data/tables/merchant_fraud_probability.csv') 
consumer_fraud['order_datetime'] = pd.to_datetime(consumer_fraud['order_datetime'])
merchant_fraud['order_datetime'] = pd.to_datetime(merchant_fraud['order_datetime'])
consumer_fraud['user_id'] = consumer_fraud['user_id'].astype('str')
merchant_fraud['merchant_abn'] = merchant_fraud['merchant_abn'].astype('str')

# %%
consumer_fraud
# Out:
#       user_id order_datetime  fraud_probability
# 0        6228     2021-12-19          97.629808
# 1       21419     2021-12-10          99.247380
# 2        5606     2021-10-17          84.058250
# 3        3101     2021-04-17          91.421921
# 4       22239     2021-10-19          94.703425
# ...       ...            ...                ...
# 34859   18466     2022-02-22           8.679873
# 34860   17552     2021-12-26           8.349463
# 34861   17875     2021-06-27           8.288847
# 34862   10401     2021-09-18           8.842216
# 34863   18076     2021-11-30           8.542029
#
# [34864 rows x 3 columns]

# %%
consumer_fraud.min()
# Out:
# user_id                                1
# order_datetime       2021-02-28 00:00:00
# fraud_probability               8.287144
# dtype: object

# %%
consumer_fraud_20 = consumer_fraud[consumer_fraud["fraud_probability"] >= 20]

# %%
consumer_fraud_20
# Out:
#       user_id order_datetime  fraud_probability
# 0        6228     2021-12-19          97.629808
# 1       21419     2021-12-10          99.247380
# 2        5606     2021-10-17          84.058250
# 3        3101     2021-04-17          91.421921
# 4       22239     2021-10-19          94.703425
# ...       ...            ...                ...
# 10544   11017     2021-09-19          20.560891
# 10625     581     2021-10-12          20.008975
# 10685    4468     2022-01-10          20.642599
# 11112    5907     2021-04-20          20.327684
# 13335    9157     2021-11-29          20.916351
#
# [5416 rows x 3 columns]

# %%
merchant_fraud
# Out:
#     merchant_abn order_datetime  fraud_probability
# 0    19492220327     2021-11-28          44.403659
# 1    31334588839     2021-10-02          42.755301
# 2    19492220327     2021-12-22          38.867790
# 3    82999039227     2021-12-19          94.134700
# 4    90918180829     2021-09-02          43.325517
# ..           ...            ...                ...
# 109  80089686333     2021-09-01          67.505811
# 110  83220249221     2021-11-27          63.512459
# 111  85482742429     2021-11-27          70.881311
# 112  11470993597     2021-09-28          63.377344
# 113  78080443264     2021-11-26          69.095317
#
# [114 rows x 3 columns]

# %%
merchant_list = merchant_fraud['merchant_abn'].tolist()

# %%
merchant_list
# Out:
# ['19492220327',
#  '31334588839',
#  '19492220327',
#  '82999039227',
#  '90918180829',
#  '31334588839',
#  '23686790459',
#  '14827550074',
#  '31334588839',
#  '19492220327',
#  '31334588839',
#  '14827550074',
#  '19492220327',
#  '93260930990',
#  '90918180829',
#  '83199298021',
#  '83199298021',
#  '94311056026',
#  '97217894162',
#  '43083074133',
#  '19492220327',
#  '99989036621',
#  '31334588839',
#  '90918180829',
#  '90918180829',
#  '90918180829',
#  '14827550074',
#  '72058040180',
#  '31334588839',
#  '82368304209',
#  '31334588839',
#  '83199298021',
#  '31334588839',
#  '91880575299',
#  '83199298021',
#  '14827550074',
#  '90918180829',
#  '67264251405',
#  '11590404675',
#  '90568944804',
#  '93260930990',
#  '35575706403',
#  '79827781481',
#  '19010030815',
#  '83199298021',
#  '90918180829',
#  '15043504837',
#  '11149063370',
#  '93260930990',
#  '83199298021',
#  '59258669983',
#  '15043504837',
#  '57564805948',
#  '27093785141',
#  '31334588839',
# ...

# %%
df3 = df

# %%
user_id_list = consumer_fraud['user_id'].tolist()

# %%
user_id_list_20 = consumer_fraud_20['user_id'].tolist()

# %%
type(user_id_list[0])
# Out:
# str

# %%
user_id_list = list(map(int, user_id_list))
merchant_list = list(map(int, merchant_list))
user_id_list_20 = list(map(int, user_id_list_20))

# %%
type(user_id_list_20[0])
# Out:
# int

# %%
type(merchant_list[0])
# Out:
# int

# %%
df2 = df

# %%
for i in merchant_list:
    df2.drop(df2[df2['merchant_abn']==i].index, inplace=True)

# %%
df
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
df2.dtypes
# Out:
# user_id                                   int64
# merchant_abn                              int64
# dollar_value                            float64
# order_datetime                           object
# state                                    object
# postcode                                  int64
# gender                                   object
# consumer_id                               int64
# name_y                                   object
# tags                                     object
# revenue_levels                           object
# take_rate                               float64
# SA2 code                                float64
# 2021                                    float64
# 2011-2021\t                             float64
# 2011-2021%                              float64
# Area                                    float64
# Population density 2021                 float64
# Earners (persons)2017-18                float64
# Median age of earners (years)2017-18    float64
# ...

# %%
df2 = df2[~df2['user_id'].isin(user_id_list)]

# %%
df3 = df3[~df3['user_id'].isin(user_id_list_20)]

# %%
df3
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
df2
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 8          22291   64203420245     10.447550     2022-04-01   VIC      3159
# 19         11146   19933438190      9.338781     2022-04-01    WA      6532
# 23         22301   87457891433     41.710616     2022-04-01    WA      6351
# 24         11148   71528203369      7.960986     2022-04-01   NSW      2646
# 25         22301   16644129035     31.736720     2022-04-01    WA      6351
# ...          ...           ...           ...            ...   ...       ...
# 3102051    24055   79417999332     72.730216     2022-08-28   QLD      4608
# 3102060    24064   81572403264     36.966756     2022-08-28   QLD      4516
# 3102061    24064   19933438190      2.382190     2022-08-28   QLD      4516
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
#
# ...

# %%
df3 = df3[~df3['merchant_abn'].isin(merchant_list)]

# %%
df3
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
import pandas as pd

# %%
df4 = pd.read_csv("../data/curated/data_half_year.csv")

# %%
df4
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
d1 = df4.drop(columns=["fraud_probability_x", "fraud_probability_y"])

# %%
d1
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0          11138   89726005175     47.782122     2022-04-01    WA      6519
# 1          11140   48248269920      0.928930     2022-04-01   VIC      3677
# 2          22286   71094934182     26.002530     2022-04-01   VIC      3172
# 3          11141   89640578182     18.435005     2022-04-01   VIC      3202
# 4          11141   24852446429      3.447834     2022-04-01   VIC      3202
# ...          ...           ...           ...            ...   ...       ...
# 3102071    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 3102074    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 3102075    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
df2.to_parquet("../data/curated/data_half_year_deleted.parquet")

# %%
df2.dtypes
# Out:
# user_id                                   int64
# merchant_abn                              int64
# dollar_value                            float64
# order_datetime                           object
# state                                    object
# postcode                                  int64
# gender                                   object
# consumer_id                               int64
# name_y                                   object
# tags                                     object
# revenue_levels                           object
# take_rate                               float64
# SA2 code                                float64
# 2021                                    float64
# 2011-2021\t                             float64
# 2011-2021%                              float64
# Area                                    float64
# Population density 2021                 float64
# Earners (persons)2017-18                float64
# Median age of earners (years)2017-18    float64
# ...

# %%
merchant_fraud["merchant_abn"] = merchant_fraud["merchant_abn"].apply(pd.to_numeric,errors='coerce')

# %%
consumer_fraud["user_id"] = consumer_fraud["user_id"].apply(pd.to_numeric,errors='coerce')

# %%
merchant_fraud.dtypes
# Out:
# merchant_abn                  int64
# order_datetime       datetime64[ns]
# fraud_probability           float64
# dtype: object

# %%
merge1 = pd.merge(d1,merchant_fraud,on='merchant_abn',how = 'inner')

# %%
merge2 = pd.merge(merge1,consumer_fraud,on='user_id',how = 'inner')

# %%
merge1
# Out:
#         user_id  merchant_abn  dollar_value order_datetime_x state  postcode  \
# 0         11146   94493496784     78.926294       2022-04-01    WA      6532
# 1         11215   94493496784     69.488626       2022-04-01   VIC      3797
# 2         11249   94493496784     70.834517       2022-04-01    WA      6121
# 3         22513   94493496784     80.308178       2022-04-01   TAS      7268
# 4         22543   94493496784    187.184046       2022-04-01   QLD      4563
# ...         ...           ...           ...              ...   ...       ...
# 150971     4105   93260930990    253.502641       2022-08-17   NSW      2400
# 150972     4105   93260930990    253.502641       2022-08-17   NSW      2400
# 150973     4105   93260930990    253.502641       2022-08-17   NSW      2400
# 150974     4105   93260930990    253.502641       2022-08-17   NSW      2400
# 150975    18105   14530561097    243.519445       2022-08-19   NSW      2642
#
# ...

# %%
merge2
# Out:
#         user_id  merchant_abn  dollar_value order_datetime_x state  postcode  \
# 0         11215   94493496784     69.488626       2022-04-01   VIC      3797
# 1         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 2         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 3         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 4         11215   21439773999     30.611221       2022-05-13   VIC      3797
# ...         ...           ...           ...              ...   ...       ...
# 218294    18124   79827781481    156.932890       2022-06-12   VIC      3862
# 218295     4555   93292821052    173.787138       2022-05-17   NSW      2582
# 218296     4555   93292821052    173.787138       2022-05-17   NSW      2582
# 218297     1863   93292821052     32.674563       2022-06-19    WA      6424
# 218298     8496   11470993597     64.136092       2022-04-04    SA      5037
#
# ...

# %%
d1 = merge2.drop(columns="fraud_probability_x")

# %%
d1
# Out:
#         user_id  merchant_abn  dollar_value order_datetime_x state  postcode  \
# 0         11215   94493496784     69.488626       2022-04-01   VIC      3797
# 1         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 2         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 3         11215   48534649627    134.710764       2022-06-27   VIC      3797
# 4         11215   21439773999     30.611221       2022-05-13   VIC      3797
# ...         ...           ...           ...              ...   ...       ...
# 218294    18124   79827781481    156.932890       2022-06-12   VIC      3862
# 218295     4555   93292821052    173.787138       2022-05-17   NSW      2582
# 218296     4555   93292821052    173.787138       2022-05-17   NSW      2582
# 218297     1863   93292821052     32.674563       2022-06-19    WA      6424
# 218298     8496   11470993597     64.136092       2022-04-04    SA      5037
#
# ...

# %%
d = merge2[["revenue_levels", "fraud_probability_x", "fraud_probability_y"]]

# %%
d3 = d.groupby("revenue_levels").mean()

# %%
d3
# Out:
#                 fraud_probability_x  fraud_probability_y
# revenue_levels
# a                         29.184748            15.140605
# b                         30.242409            15.146840
# c                         29.696452            15.129670
# d                         63.377344            15.886387
# e                         69.095317            14.870413

# %%
d3.columns = ["merchant_fraud_mean_prob","consumer_fraud_mean_prob"]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.bar(d3.index, d3.merchant_fraud_mean_prob)
plt.title("Revenue level vs Merchant mean fraud probability")
plt.xlabel("Revenue Levels")
plt.ylabel("Mean Fraud Prob")
plt.rcParams['figure.figsize'] = (10, 6)
plt.savefig('../plots/merchant_fraud_prob.png')
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(d3.index, d3.consumer_fraud_mean_prob)
plt.title("Revenue level vs Consumer mean fraud probability")
plt.xlabel("Revenue Levels")
plt.ylabel("Mean Fraud Prob")
plt.rcParams['figure.figsize'] = (10, 6)
plt.savefig('../plots/consumer_fraud_prob.png')
plt.show()

# %%
aa = pd.read_parquet("../data/curated/data_half_year_deleted.parquet")

# %%
aa
# Out:
#          user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 8          22291   64203420245     10.447550     2022-04-01   VIC      3159
# 19         11146   19933438190      9.338781     2022-04-01    WA      6532
# 23         22301   87457891433     41.710616     2022-04-01    WA      6351
# 24         11148   71528203369      7.960986     2022-04-01   NSW      2646
# 25         22301   16644129035     31.736720     2022-04-01    WA      6351
# ...          ...           ...           ...            ...   ...       ...
# 3102051    24055   79417999332     72.730216     2022-08-28   QLD      4608
# 3102060    24064   81572403264     36.966756     2022-08-28   QLD      4516
# 3102061    24064   19933438190      2.382190     2022-08-28   QLD      4516
# 3102072    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 3102073    24080   89640578182     21.837852     2022-08-28   NSW      2809
#
# ...

# %%
d3.to_parquet("../data/curated/rev_level_fraud_prob.parquet")

# %%
import pandas as pd

# %%
dd = pd.read_csv("../data/curated/data_half_year.csv")

# %%
from datetime import datetime 
import datetime as dt
data_started = datetime.strptime('2022-02-28', '%Y-%m-%d') # start date of data
data_ended = datetime.strptime('2022-08-28', '%Y-%m-%d') # end date of data

transaction_3 = pd.DataFrame() # store the data
date_i = datetime.strptime('2022-02-28', '%Y-%m-%d')

while date_i <= data_ended:
    data = pd.read_parquet('../data/tables/transactions_20220228_20220828_snapshot/order_datetime={}'.format(
        date_i.strftime("%Y-%m-%d")))  ## collect the daily transaction data
    
    data['date'] = date_i
    
    transaction_3 = pd.concat([transaction_3,data],axis = 0)
    if date_i.day == 1:
        print(date_i.strftime("%Y-%m-%d"),'done!')
    date_i += dt.timedelta(days=1)
# Out:
# 2022-03-01 done!
# 2022-04-01 done!
# 2022-05-01 done!
# 2022-06-01 done!
# 2022-07-01 done!
# 2022-08-01 done!

# %%
transaction = pd.read_parquet("../data/curated/cleaned_merge3_old.parquet")
transaction_new = pd.read_parquet("../data/curated/cleaned_merge3.parquet")
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
transaction_all = pd.concat([transaction,transaction_new],axis = 0)

# %%
transaction_all
# Out:
#         user_id merchant_abn  dollar_value  \
# 0             1  28000487688    133.226894
# 1         18485  62191208634     79.131400
# 2             1  83690644458     30.441348
# 4             2  80779820715     48.123977
# 5         18489  43186523025     98.148785
# ...         ...          ...           ...
# 4508101   14931  94455880010     93.759048
# 4508102   14931  35755909141    124.307113
# 4508103   14931  79417999332    131.169882
# 4508104   14932  46804135891     37.889414
# 4508105   14932  35223308778    196.988323
#
#                                      order_id       date             name_x  \
# 0        0c37b3f7-c7f1-48cb-bcc7-0a58e76608ea 2021-02-28   Yolanda Williams
# 1        9e18b913-0465-4fd4-92fd-66d15e65d93c 2021-02-28      Samuel Haynes
# 2        40a2ff69-ea34-4657-8429-df7ca957d6a1 2021-02-28   Yolanda Williams
# 4        cd09bdd6-f56d-489f-81ea-440f4bda933c 2021-02-28         Mary Smith
# ...

# %%
merge_output = pd.read_parquet("../data/curated/merge6.parquet")

# %%
merge_output
# Out:
#         user_id merchant_abn  dollar_value  \
# 0             1  28000487688    133.226894
# 1         18485  62191208634     79.131400
# 2             1  83690644458     30.441348
# 3             2  80779820715     48.123977
# 4         18489  43186523025     98.148785
# ...         ...          ...           ...
# 3028545   18461  81219314324     39.072718
# 3028546   18462  80324045558      5.393613
# 3028548   18471  21359184622     97.760164
# 3028549   18472  21807339153     54.310599
# 3028551   18477  63290521567     17.826070
#
#                                      order_id       date              name_x  \
# 0        0c37b3f7-c7f1-48cb-bcc7-0a58e76608ea 2021-02-28    Yolanda Williams
# 1        9e18b913-0465-4fd4-92fd-66d15e65d93c 2021-02-28       Samuel Haynes
# 2        40a2ff69-ea34-4657-8429-df7ca957d6a1 2021-02-28    Yolanda Williams
# 3        cd09bdd6-f56d-489f-81ea-440f4bda933c 2021-02-28          Mary Smith
# ...

# %%
dd['order_datetime'] = pd.to_datetime(dd['order_datetime'])

# %%
merge_output = merge_output.rename(columns={'date':'order_datetime'})

# %%
customer_f = pd.merge(merge_output,consumer_fraud,on = ['order_datetime','user_id'])
merchant_f = pd.merge(merge_output,merchant_fraud,on = ['order_datetime','merchant_abn'])

# %%
f1 = pd.concat([customer_f,merchant_f],axis = 0).drop_duplicates()

# %%
f2 = f1.drop(['fraud_probability'],axis = 1).drop_duplicates()

# %%
dataset = f1.loc[f2.index,:].dropna()

# %%
dataset
# Out:
#      user_id merchant_abn  dollar_value                              order_id  \
# 0      21989  14430838529     74.674454  f539f668-d07b-4685-a082-fd017088e4bc
# 1       4144  45629217853      3.167339  27ba867c-cb07-43a7-8848-4a2791b3933c
# 2       4351  64203420245     49.474965  e181ac26-22fd-42dc-b73d-03f97a43a765
# 3       5209  75944642726     11.590398  767bf7b4-3f42-4d3f-a4fc-c1d81c67f58c
# 4       5209  86578477987     22.085383  d44ae630-2dd7-4f98-afb1-ef6c9cee23a3
# ...      ...          ...           ...                                   ...
# 4056   16681  96420684134     40.774364  bdcfd200-e163-49f4-803d-c4e2e86f6875
# 4057   17555  11841065357     51.786482  a13872ff-cf23-4a04-8d3a-69f2ab74e6d0
# 4058   17555  30942453214     23.393562  6baa1c44-81d7-4c4e-baac-9f3450516dba
# 4059   17555  67142049268    141.283651  5ac0ad7b-8b8f-4c08-b310-fa849c1b4546
# 4060   17935  53132768930     35.057394  0b79fe05-eed2-44f6-865a-3522cf917cb3
#
# ...

# %%
dataset.to_parquet("../data/curated/ml.parquet")

# %%
import pandas as pd

# %%
r = pd.read_csv("../data/curated/merge_new2.csv")

# %%
r
# Out:
#           user_id  merchant_abn  dollar_value order_datetime state  postcode  \
# 0               1   28000487688    133.226894     2021-02-28    WA      6935
# 1           18485   62191208634     79.131400     2021-02-28   VIC      3073
# 2               1   83690644458     30.441348     2021-02-28    WA      6935
# 3               2   80779820715     48.123977     2021-02-28   NSW      2782
# 4           18489   43186523025     98.148785     2021-02-28   VIC      3378
# ...           ...           ...           ...            ...   ...       ...
# 10440632    24076   95896852636     62.756384     2022-08-28   VIC      3469
# 10440633    24077   80779820715     56.650642     2022-08-28   QLD      4474
# 10440634    24080   89640578182     21.837852     2022-08-28   NSW      2809
# 10440635    24081   63290521567     19.628920     2022-08-28   VIC      3980
# 10440636    24081   68216911708     35.192603     2022-08-28   VIC      3980
#
# ...

# %%
r2 = pd.read_csv("../data/curated/dataset3_cleaned.csv")

# %%
r2
# Out:
#          user_id  merchant_abn  dollar_value  \
# 0              1   96152467973     24.045785
# 1          22284   29362189014     68.955569
# 2              2   91923722701      5.848609
# 3          22284   82065156333      9.788732
# 4          22284   74019238521      3.410656
# ...          ...           ...           ...
# 3665374    24076   95896852636     62.756384
# 3665375    24077   80779820715     56.650642
# 3665376    24080   89640578182     21.837852
# 3665377    24081   63290521567     19.628920
# 3665378    24081   68216911708     35.192603
#
#                                      order_id        date            name_x  \
# 0        fbd6ce4d-47ac-435c-bf42-bf696ec0961b  2022-02-28  Yolanda Williams
# 1        a0b0d044-92b1-48ba-84c6-1431e56281b5  2022-02-28     Sarah Daniels
# 2        229dea28-df16-44f0-adc5-47988fd5c771  2022-02-28        Mary Smith
# 3        54da70f5-5cdd-473f-8525-f01208690500  2022-02-28     Sarah Daniels
# ...

# %%
## duplicated 
consumer_fraud = consumer_fraud.drop_duplicates()
merchant_fraud = merchant_fraud.drop_duplicates()

# %%
r['order_datetime'] = pd.to_datetime(r['order_datetime'])

# %%
r[['user_id', 'merchant_abn']] = r[['user_id', 'merchant_abn']].apply(str)

# %%
customer_f = pd.merge(r,consumer_fraud,on = ['order_datetime','user_id'])
merchant_f = pd.merge(r,merchant_fraud,on = ['order_datetime','merchant_abn'])

# %%
f1 = pd.concat([customer_f,merchant_f],axis = 0).drop_duplicates()
f2 = f1.drop(['fraud_probability'],axis = 1).drop_duplicates()

# %%
consumer_fraud
# Out:
#       user_id order_datetime  fraud_probability
# 0        6228     2021-12-19          97.629808
# 1       21419     2021-12-10          99.247380
# 2        5606     2021-10-17          84.058250
# 3        3101     2021-04-17          91.421921
# 4       22239     2021-10-19          94.703425
# ...       ...            ...                ...
# 34859   18466     2022-02-22           8.679873
# 34860   17552     2021-12-26           8.349463
# 34861   17875     2021-06-27           8.288847
# 34862   10401     2021-09-18           8.842216
# 34863   18076     2021-11-30           8.542029
#
# [34765 rows x 3 columns]

# %%
dataset = f1.loc[f2.index,:].dropna()

# %%
dataset
# Out:
# Empty DataFrame
# Columns: [user_id, merchant_abn, dollar_value, order_datetime, state, postcode, gender, consumer_id, name_y, tags, revenue_levels, take_rate, SA2 code, 2021, 2011-2021	, 2011-2021%, Area, Population density 2021, Earners (persons)2017-18, Median age of earners (years)2017-18, Sum ($)2017-18, Median ($)2017-18, Mean ($)2017-18, fraud_probability_x, fraud_probability_y, fraud_probability]
# Index: []
#
# [0 rows x 26 columns]
